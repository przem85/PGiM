# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Zadanie 1
# Proszę zmienić kolor 100 wybranym pikselom na obrazie LENA_512.

# %% [markdown]
# ## Zadanie 2
# Proszę wyświetlić obraz LENA_512 w odcianiach szarości.

# %% [markdown]
# ## Zadanie 3
# Proszę wyświetlić obraz LENA_512 w odcianiach szarości uśredniając kolory bez użycia funkcji cv2.COLOR_GRAY2RGB.

# %% [markdown]
# # Zadnie 4
# Proszę wyświetlić obrazek: LENA_512 oraz Statek_640_505	jako negatyw.

# %% [markdown]
# ## Zadanie 5
#
# Proszę wyświetlić obrazy: LENA_512 oraz Statek_640_505 jako sepię
#
#   * Zapisz zdjęcie w odcieniach szarości
#   * Zapisz współrzędne RGB jako
# $$
# R'=R+2W
# $$
# $$
# G'=G+W
# $$
# $$
# B'=B
# $$
#
# gdzie
#
# $$
# W=20 \ldots 40
# $$

# %% [markdown]
# ## Zadanie 6
# Proszę wyświetlić: LENA_512 obrócona o kąt $30$, $45$, $90$, stopni. Zgodnie ze wzorem:
# $$
# x' = x \cos(\theta) −y \sin(\theta)
# $$
# $$
# y'= x sin(\theta) + y cos(\theta)
# $$

# %% [markdown]
# ## Zadanie 7
# Proszę wyświetlić przesunięty obraz: LENA_512.

# %% [markdown]
# # Zadanie 8
#
# Zmiana poziomów jasności. Niech $B = 8$. Gdy $B = 8$ mamy do dyspozycji $8^2−1$ poziomów jasności (zdjęcie czarno-białe). Użyj LUT (Lookup table). Proszę narysować LENA_512.
# w różnych odcieniach szarości dla $newB=1,2,3,4,5,8$. Skorzystaj ze wzoru:
#
# $$
# delta=
# \frac{2^{B}}{2^{newB}}
# $$
#
# $$
# L'(x,y)=floor\left(max\left(
# \frac{(L(x,y)-(
# \frac{delta}{2}
# )-1)
# }{delta}
# ,0 \right) \right) \cdot delta+\left(
# \frac{delta}{2}-1 \right)
# $$
#
# Wypróbuj program na obrazku WIR_360
#
# ![alt](https://raw.githubusercontent.com/przem85/PGiM/master/img/WIR_360.jpg)
